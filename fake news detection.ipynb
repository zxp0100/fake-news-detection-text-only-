# %%
import re
import nltk
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from collections import Counter
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.util import ngrams
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import PassiveAggressiveClassifier, LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, Dense, Dropout, Input, LSTM, Reshape
from wordcloud import WordCloud

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('vader_lexicon')


### FUNCTION USED ###
def print_label_statistics(df, dataset_name):
    """Prints the count and percentage of labels for a given dataset."""
    label_counts = df["label"].value_counts()
    label_percentage = (df["label"].value_counts(normalize=True) * 100).round(2)
    
    label_stats = pd.DataFrame({"Count": label_counts, "Percentage": label_percentage})
    
    print(f"{dataset_name} :")
    print(label_stats)
    print("\n") 

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words("english"))
    tokens = [word for word in tokens if word not in stop_words]
    pos_tags = pos_tag(tokens)
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in pos_tags]
    tokens = [word for word in tokens if len(word) > 2]
    return " ".join(tokens)

def get_top_ngrams(texts, n=1, top_k=10):
    """Function to extract top n-grams (unigram or bigram)."""
    ngram_list = []
    for text in texts:
        tokens = text.split()
        ngram_list.extend(ngrams(tokens, n))
    
    ngram_freq = Counter(ngram_list).most_common(top_k)
    return ngram_freq

def build_bilstm_model(input_dim):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(256, activation='relu'),
        Dropout(0.3),
        Dense(128, activation='relu'),
        Reshape((128, 1)),
        Bidirectional(LSTM(64, return_sequences=True)),
        Dropout(0.3),
        Bidirectional(LSTM(32)),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model    

def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['False', 'True'], yticklabels=['False', 'True'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(title)
    plt.show()


# Read datasets
liar_df = pd.read_excel(r"C:\Users\pzx12\OneDrive\Desktop\dataset\liar_combineddataset.xlsx", header=None)
fake_news_df = pd.read_json(r"C:\Users\pzx12\OneDrive\Desktop\dataset\fake_news_db.json")

liar_df = liar_df[[2, 1]]
liar_df.columns = ["statement", "label"]
liar_df["label"] = liar_df["label"].replace({"half-true": True, "mostly-true": True, "pants-fire": False, "barely-true": False})

fake_news_df = fake_news_df.iloc[:, [2, 8]]
fake_news_df.columns = ['statement', 'label']
fake_news_df = fake_news_df[fake_news_df['label'].isin(['true', 'false'])].replace({'label': {'true': True, 'false': False}}).dropna()

 
# Check the distribution of each dataset
print_label_statistics(liar_df, "LIAR")
print_label_statistics(fake_news_df, "FND")

# Sample equal data from both datasets
df = pd.concat([liar_df.groupby("label").sample(n=2000, random_state=42),
                fake_news_df.groupby("label").sample(n=2000, random_state=42)], ignore_index=True)


# Apply text preprocessing function to the 'statement' column
df["clean_text"] = df["statement"].apply(preprocess_text)


# Sentiment Analysis using VADER
sia = SentimentIntensityAnalyzer()
df["sentiment"] = df["statement"].apply(lambda x: sia.polarity_scores(str(x))["compound"] + 1)


## BASIC STATISTICS FOR 'clean_text' COLUMN ##
# Word Count
df["word_count"] = df["clean_text"].apply(lambda x: len(x.split()))
df["unique_word_count"] = df["clean_text"].apply(lambda x: len(set(x.split())))

print("WordCount Statistics :")
print(df[["word_count", "unique_word_count"]].describe())

# Get top unigrams and bigrams
top_unigrams = get_top_ngrams(df["clean_text"], n=1, top_k=10)
top_bigrams = get_top_ngrams(df["clean_text"], n=2, top_k=10)

# Visualization of unigrams and bigrams
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Unigram Plot
unigram_words, unigram_freqs = zip(*top_unigrams)
sns.barplot(x=list(unigram_freqs), y=[" ".join(word) for word in unigram_words], ax=axes[0], palette="viridis")
axes[0].set_title("Top 10 Unigrams")
axes[0].set_xlabel("Frequency")

# Display values on bars
for container in axes[0].containers:
    axes[0].bar_label(container, fmt="%d", padding=3)

# Bigram Plot
bigram_words, bigram_freqs = zip(*top_bigrams)
sns.barplot(x=list(bigram_freqs), y=[" ".join(word) for word in bigram_words], ax=axes[1], palette="magma")
axes[1].set_title("Top 10 Bigrams")
axes[1].set_xlabel("Frequency")

# Display values on bars
for container in axes[1].containers:
    axes[1].bar_label(container, fmt="%d", padding=3)

plt.tight_layout()
plt.show()


## BASIC SENTIMENT ANALYSIS ##
# Overall statistics 
print("Overall Sentiment Score:")
print(df["sentiment"].describe())
print("Mode:", df["sentiment"].mode().values)

# Statistic based on each label
df_true = df[df["label"] == True]
df_false = df[df["label"] == False]

print("\nSentiment Score for 'True' :")
print(df_true["sentiment"].describe())
print("Mode:", df_true["sentiment"].mode().values)

print("\nSentiment Score for 'False' :")
print(df_false["sentiment"].describe())
print("Mode:", df_false["sentiment"].mode().values)


# TF-IDF Vectorization
vectorizer = TfidfVectorizer(max_features=10000, ngram_range=(1, 2))
X_tfidf = vectorizer.fit_transform(df["clean_text"])
X_tfidf_df = pd.DataFrame(X_tfidf.toarray())
X_tfidf_df.columns = X_tfidf_df.columns.astype(str)

# Extract sentiment data
X_sentiment = df[["sentiment"]].reset_index(drop=True)

# Create a dictionary containing different feature sets
X_sets = {
    "TF-IDF": X_tfidf_df,
    "TF-IDF + Sentiment": pd.concat([X_tfidf_df, X_sentiment], axis=1)
}


## Train and evaluate individual machine learning models and ensemble models (hard and soft voting), with or without sentiment scores  
for set_name, X_final in X_sets.items():
    print(f"Evaluating feature set: {set_name}\n")
    X_train, X_test, y_train, y_test = train_test_split(X_final, df['label'], test_size=0.2, random_state=42, stratify=df['label'])

    # Initialize traditional machine learning models
    rf = RandomForestClassifier(n_estimators=100, random_state=42)
    pa = PassiveAggressiveClassifier(max_iter=1000, random_state=42)
    svm = SVC(kernel='linear', probability=True, random_state=42)
    lr = LogisticRegression(max_iter=1000, random_state=42)
    nb = MultinomialNB()
    
    models = [("Random Forest", rf), ("PA Classifier", pa), ("SVM", svm), ("Logistic Regression", lr), ("Naive Bayes", nb)]
    
    predictions, probabilities = [], []
    for name, model in models:
        model.fit(X_train, y_train)    
        y_pred = model.predict(X_test)
        plot_confusion_matrix(y_test, y_pred, title=f"Confusion Matrix - {name}")
        predictions.append(y_pred)
        if hasattr(model, "predict_proba"):
            probabilities.append(model.predict_proba(X_test)[:, 1])
        elif hasattr(model, "decision_function"):
            probabilities.append((model.decision_function(X_test) - model.decision_function(X_test).min()) / 
                (model.decision_function(X_test).max() - model.decision_function(X_test).min()))
        print(f"\nClassification Report - {name}:")
        print(classification_report(y_test, y_pred))

    
    # Train a Bi-LSTM model
    bilstm = build_bilstm_model(X_train.shape[1])
    bilstm.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
    bilstm_preds = (bilstm.predict(X_test) > 0.5).astype("int32").flatten()
    plot_confusion_matrix(y_test, bilstm_preds, title="Confusion Matrix - BI-LSTM")
    bilstm_probs = bilstm.predict(X_test).flatten()
    
    print("\nClassification Report - BI-LSTM:")
    print(classification_report(y_test, bilstm_preds))

    
    # Hard voting ensemble
    hard_voting_preds = np.array(predictions + [bilstm_preds]).T
    final_hard_preds = [np.bincount(row).argmax() for row in hard_voting_preds]

    # Soft voting ensemble
    final_soft_preds = (np.column_stack(probabilities + [bilstm_probs]).mean(axis=1) > 0.5).astype(int)

    plot_confusion_matrix(y_test, final_hard_preds, title="Confusion Matrix - Hard Voting")
    print("\nClassification Report - Hard Voting Ensemble:")
    print(classification_report(y_test, final_hard_preds))
    plot_confusion_matrix(y_test, final_soft_preds, title="Confusion Matrix - Soft Voting")
    print("\nClassification Report - Soft Voting Ensemble:")
    print(classification_report(y_test, final_soft_preds))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pzx12\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pzx12\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\pzx12\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pzx12\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\pzx12\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# LIAR :
#        Count  Percentage
# label
# True    7134       55.77
# False   5657       44.23
#
#
# FND :
#        Count  Percentage
# label
# False  53150       95.67
# True    2405        4.33
#
#
# WordCount Statistics :
#         word_count  unique_word_count
# count  8000.000000        8000.000000
# mean     11.461750          10.791625
# std       9.762592           8.079317
# min       0.000000           0.000000
# 25%       7.000000           7.000000
# 50%       9.000000           9.000000
# 75%      13.000000          12.000000
# max     250.000000         180.000000
# Overall Sentiment Score:
# count    8000.000000
# mean        0.958603
# std         0.397685
# min         0.006900
# 25%         0.684350
# 50%         1.000000
# 75%         1.180650
# max         1.982800
# Name: sentiment, dtype: float64
# Mode: [1.]
#
# Sentiment Score for 'True' :
# count    4000.00000
# mean        0.97420
# std         0.38248
# min         0.01580
# 25%         0.70400
# 50%         1.00000
# 75%         1.20230
# max         1.94230
# Name: sentiment, dtype: float64
# Mode: [1.]
#
# Sentiment Score for 'False' :
# count    4000.000000
# mean        0.943007
# std         0.411787
# min         0.006900
# 25%         0.660000
# 50%         1.000000
# 75%         1.177900
# max         1.982800
# Name: sentiment, dtype: float64
# Mode: [1.]
# Evaluating feature set: TF-IDF
# Classification Report - Random Forest:
#               precision    recall  f1-score   support
#
#        False       0.65      0.62      0.64       800
#         True       0.64      0.67      0.65       800
#
#     accuracy                           0.64      1600
#    macro avg       0.64      0.64      0.64      1600
# weighted avg       0.64      0.64      0.64      1600
# Classification Report - PA Classifier:
#               precision    recall  f1-score   support
#
#        False       0.63      0.62      0.62       800
#         True       0.62      0.63      0.63       800
#
#     accuracy                           0.63      1600
#    macro avg       0.63      0.63      0.63      1600
# weighted avg       0.63      0.63      0.63      1600
# Classification Report - SVM:
#               precision    recall  f1-score   support
#
#        False       0.66      0.64      0.65       800
#         True       0.65      0.67      0.66       800
#
#     accuracy                           0.66      1600
#    macro avg       0.66      0.66      0.66      1600
# weighted avg       0.66      0.66      0.66      1600
# Classification Report - Logistic Regression:
#               precision    recall  f1-score   support
#
#        False       0.66      0.65      0.66       800
#         True       0.66      0.67      0.66       800
#
#     accuracy                           0.66      1600
#    macro avg       0.66      0.66      0.66      1600
# weighted avg       0.66      0.66      0.66      1600
# Classification Report - Naive Bayes:
#               precision    recall  f1-score   support
#
#        False       0.68      0.67      0.67       800
#         True       0.67      0.69      0.68       800
#
#     accuracy                           0.68      1600
#    macro avg       0.68      0.68      0.68      1600
# weighted avg       0.68      0.68      0.68      1600
#
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.5140 - loss: 0.6891 - val_accuracy: 0.6569 - val_loss: 0.6219
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.7849 - loss: 0.4796 - val_accuracy: 0.6600 - val_loss: 0.6633
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9094 - loss: 0.2368 - val_accuracy: 0.6531 - val_loss: 0.8375
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 71ms/step - accuracy: 0.9694 - loss: 0.0891 - val_accuracy: 0.6406 - val_loss: 1.4681
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9926 - loss: 0.0205 - val_accuracy: 0.6344 - val_loss: 1.6763
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - accuracy: 0.9959 - loss: 0.0111 - val_accuracy: 0.6338 - val_loss: 2.3875
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9987 - loss: 0.0041 - val_accuracy: 0.6375 - val_loss: 2.3888
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.9982 - loss: 0.0031 - val_accuracy: 0.6438 - val_loss: 2.6474
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - accuracy: 0.9985 - loss: 0.0054 - val_accuracy: 0.6338 - val_loss: 2.3019
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 75ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.6363 - val_loss: 2.5902
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#
# Classification Report - BI-LSTM:
#               precision    recall  f1-score   support
#
#        False       0.62      0.68      0.65       800
#         True       0.65      0.59      0.62       800
#
#     accuracy                           0.64      1600
#    macro avg       0.64      0.64      0.64      1600
# weighted avg       0.64      0.64      0.64      1600
# Classification Report - Hard Voting Ensemble:
#               precision    recall  f1-score   support
#
#        False       0.66      0.70      0.68       800
#         True       0.68      0.64      0.66       800
#
#     accuracy                           0.67      1600
#    macro avg       0.67      0.67      0.67      1600
# weighted avg       0.67      0.67      0.67      1600
# Classification Report - Soft Voting Ensemble:
#               precision    recall  f1-score   support
#
#        False       0.65      0.69      0.67       800
#         True       0.67      0.64      0.65       800
#
#     accuracy                           0.66      1600
#    macro avg       0.66      0.66      0.66      1600
# weighted avg       0.66      0.66      0.66      1600
#
# Evaluating feature set: TF-IDF + Sentiment
# Classification Report - Random Forest:
#               precision    recall  f1-score   support
#
#        False       0.66      0.64      0.65       800
#         True       0.65      0.67      0.66       800
#
#     accuracy                           0.65      1600
#    macro avg       0.65      0.65      0.65      1600
# weighted avg       0.65      0.65      0.65      1600
# Classification Report - PA Classifier:
#               precision    recall  f1-score   support
#
#        False       0.64      0.58      0.61       800
#         True       0.62      0.68      0.65       800
#
#     accuracy                           0.63      1600
#    macro avg       0.63      0.63      0.63      1600
# weighted avg       0.63      0.63      0.63      1600
# Classification Report - SVM:
#               precision    recall  f1-score   support
#
#        False       0.66      0.65      0.65       800
#         True       0.65      0.67      0.66       800
#
#     accuracy                           0.66      1600
#    macro avg       0.66      0.66      0.66      1600
# weighted avg       0.66      0.66      0.66      1600
# Classification Report - Logistic Regression:
#               precision    recall  f1-score   support
#
#        False       0.66      0.66      0.66       800
#         True       0.66      0.67      0.67       800
#
#     accuracy                           0.66      1600
#    macro avg       0.66      0.66      0.66      1600
# weighted avg       0.66      0.66      0.66      1600
# Classification Report - Naive Bayes:
#               precision    recall  f1-score   support
#
#        False       0.69      0.66      0.67       800
#         True       0.67      0.70      0.68       800
#
#     accuracy                           0.68      1600
#    macro avg       0.68      0.68      0.68      1600
# weighted avg       0.68      0.68      0.68      1600
#
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.5005 - loss: 0.6928 - val_accuracy: 0.6219 - val_loss: 0.6514
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.7487 - loss: 0.5424 - val_accuracy: 0.6569 - val_loss: 0.6312
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.8773 - loss: 0.3207 - val_accuracy: 0.6488 - val_loss: 0.7564
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9577 - loss: 0.1402 - val_accuracy: 0.6300 - val_loss: 0.9853
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 71ms/step - accuracy: 0.9859 - loss: 0.0519 - val_accuracy: 0.6444 - val_loss: 1.4585
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - accuracy: 0.9958 - loss: 0.0162 - val_accuracy: 0.6413 - val_loss: 1.6026
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 75ms/step - accuracy: 0.9978 - loss: 0.0091 - val_accuracy: 0.6450 - val_loss: 1.9929
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 81ms/step - accuracy: 0.9966 - loss: 0.0088 - val_accuracy: 0.6356 - val_loss: 2.5325
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.9990 - loss: 0.0024 - val_accuracy: 0.6313 - val_loss: 1.9825
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9979 - loss: 0.0038 - val_accuracy: 0.6406 - val_loss: 2.0495
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#
# Classification Report - BI-LSTM:
#               precision    recall  f1-score   support
#
#        False       0.64      0.64      0.64       800
#         True       0.64      0.64      0.64       800
#
#     accuracy                           0.64      1600
#    macro avg       0.64      0.64      0.64      1600
# weighted avg       0.64      0.64      0.64      1600
# Classification Report - Hard Voting Ensemble:
#               precision    recall  f1-score   support
#
#        False       0.67      0.70      0.68       800
#         True       0.68      0.65      0.67       800
#
#     accuracy                           0.67      1600
#    macro avg       0.67      0.67      0.67      1600
# weighted avg       0.67      0.67      0.67      1600
# Classification Report - Soft Voting Ensemble:
#               precision    recall  f1-score   support
#
#        False       0.66      0.67      0.67       800
#         True       0.67      0.66      0.66       800
#
#     accuracy                           0.66      1600
#    macro avg       0.66      0.66      0.66      1600
# weighted avg       0.66      0.66      0.66      1600
